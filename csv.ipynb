# %%
b = open('data.csv','x')
b.close()

# %%
b = open('data.csv','r')
print(b.read())
b.close()
# Out:
# Name,Age,Address
# Ram,67,Kathmandu
# Shyam,45,Patan
# Hari,45,Bhaktapur
# Binita,45,Bara
# Nabin,34,Simara
# Nabina,23,Kathmandu

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#      Name  Age    Address
# 0     Ram   67  Kathmandu
# 1   Shyam   45      Patan
# 2    Hari   45  Bhaktapur
# 3  Binita   45       Bara
# 4   Nabin   34     Simara
# 5  Nabina   23  Kathmandu

# %%
b = open('data1.csv','w')
b.write('Name,Age,Address,Phone\n')
b.close()

infos = ''
for i in range(2):
    name = input("Enter name = ")
    age = int(input("Enter age = "))
    add = input("Enter address = ")
    phone = int(input("Enter phone = "))

    info = f"{name},{age},{add},{phone}\n"
    infos = infos+info
    
print(infos)

b = open('data1.csv','a')
b.write(infos)
b.close()
# Out:
# Enter name = Ram
# Enter age = 78
# Enter address = Kathmandu
# Enter phone = 9856554543
# Enter name = Shyam
# Enter age = 78
# Enter address = Bara
# Enter phone = 9867665654
# Ram,78,Kathmandu,9856554543
# Shyam,78,Bara,9867665654

# %%
import pandas as pd
df = pd.read_csv('data1.csv')
df
# Out:
#     Name  Age    Address       Phone
# 0    Ram   78  Kathmandu  9856554543
# 1  Shyam   78       Bara  9867665654

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows=5)
df
# Out:
#      Name  Age    Address
# 0     Ram   67  Kathmandu
# 1   Shyam   45      Patan
# 2    Hari   45  Bhaktapur
# 3  Binita   45       Bara
# 4   Nabin   34     Simara

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head(6)
# Out:
#      Name  Age    Address
# 0     Ram   67  Kathmandu
# 1   Shyam   45      Patan
# 2    Hari   45  Bhaktapur
# 3  Binita   45       Bara
# 4   Nabin   34     Simara
# 5  Nabina   23  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.tail(4)
# Out:
#      Name  Age    Address
# 2    Hari   45  Bhaktapur
# 3  Binita   45       Bara
# 4   Nabin   34     Simara
# 5  Nabina   23  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df
# Out:
#         Age    Address
# Name
# Ram      67  Kathmandu
# Shyam    45      Patan
# Hari     45  Bhaktapur
# Binita   45       Bara
# Nabin    34     Simara
# Nabina   23  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 0)
df
# Out:
#         Age    Address
# Name
# Ram      67  Kathmandu
# Shyam    45      Patan
# Hari     45  Bhaktapur
# Binita   45       Bara
# Nabin    34     Simara
# Nabina   23  Kathmandu

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 0,usecols = ['Name','Age'])
df
# Out:
#         Age
# Name
# Ram      67
# Shyam    45
# Hari     45
# Binita   45
# Nabin    34
# Nabina   23

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 0)
df.iloc[0:4]
# Out:
#         Age    Address
# Name
# Ram      67  Kathmandu
# Shyam    45      Patan
# Hari     45  Bhaktapur
# Binita   45       Bara

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 0)
df.iloc[0:4,0:1]
# Out:
#         Age
# Name
# Ram      67
# Shyam    45
# Hari     45
# Binita   45

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 0)
df.loc['Ram':'Nabin']
# Out:
#         Age    Address
# Name
# Ram      67  Kathmandu
# Shyam    45      Patan
# Hari     45  Bhaktapur
# Binita   45       Bara
# Nabin    34     Simara

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df[df['Name'] == 'Shyam']
# Out:
#     Name  Age Address
# 1  Shyam   45   Patan

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df[df['Age'] >40]
# Out:
#      Name  Age    Address
# 0     Ram   67  Kathmandu
# 1   Shyam   45      Patan
# 2    Hari   45  Bhaktapur
# 3  Binita   45       Bara

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df[(df['Age'] >40) & (df['Address'] == 'Kathmandu')]
# Out:
#   Name  Age    Address
# 0  Ram   67  Kathmandu

# %%
import pandas as pd
data = {'Roll': [1, 2], 'Name': ['Ram', 'Shyam'], 'Age': [45, 78], 'Address': ['Kathmandu', 'Patan']}
my_data_frame = pd.DataFrame(data)
my_data_frame.to_csv('my_data_frame.csv')

# %%
# DataFrame
b = {}
rol = []
na = []
ag = []
add = []
n = int(input("ENtre how many rows = "))
for i in range(1,n+1):
    name = input("Enter name = ")
    age = int(input("Enter age = "))
    address = input("Enter address = ")
    rol.append(i)
    na.append(name)
    ag.append(age)
    add.append(address)

b = {'Roll':rol,'Name':na,'Age':ag,'Address':add}
import pandas as pd
data_frame = pd.DataFrame(b)
data_frame.to_csv('info.csv')
data_frame
# Out:
# ENtre how many rows = 7
# Enter name = ram
# Enter age = 555
# Enter address = hgajaj
# Enter name = nabin
# Enter age = 85
# Enter address = hhjfj
# Enter name = nabina
# Enter age = 87
# Enter address = hjgjf
# Enter name = subash
# Enter age = 46
# Enter address = khagag
# Enter name = sigdel
# Enter age = 95
# Enter address = 8797
# Enter name = hari
# Enter age = 88
# Enter address = 4554
# Enter name = bahadur
# Enter age = 85
# Enter address = gfdgfd
#    Roll     Name  Age Address
# 0     1      ram  555  hgajaj
# 1     2    nabin   85   hhjfj
# 2     3   nabina   87   hjgjf
# 3     4   subash   46  khagag
# 4     5   sigdel   95    8797
# 5     6     hari   88    4554
# 6     7  bahadur   85  gfdgfd

# %%
import pandas as pd
df = pd.read_csv('info.csv',index_col = 0)
df = df.drop(['ram','nabin','nabina'],axis = 0)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-87da113de6d3> in <module>
#       1 import pandas as pd
#       2 df = pd.read_csv('info.csv',index_col = 0)
# ----> 3 df = df.drop(['ram','nabin','nabina'],axis = 0)
#       4 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
# ...

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Age')
df = df.drop([45,67],axis = 0)
df
# Out:
#        Name    Address
# Age
# 34    Nabin     Simara
# 23   Nabina  Kathmandu

# %%
# WAP to append data in csv file using list inside list
# WAP to concate two or more dataframes
